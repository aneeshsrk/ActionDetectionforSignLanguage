# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.13.0 opencv-python mediapipe scikit-learn matplotlib pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (2.12.0)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: mediapipe in c:\programdata\anaconda3\lib\site-packages (0.10.7)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: pygame in c:\users\ashok\appdata\roaming\python\python311\site-packages (2.5.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.20)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.59.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.38.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ashok\appdata\roaming\python\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import pygame
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['L'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 0

# %%
for action in actions: 
    #dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    #for sequence in range(1,no_sequences+1):
     for sequence in range(no_sequences):
        try: 
            #os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
pygame.init()
pygame.mixer.init()
ready_sound=pygame.mixer.Sound("getready.wav")
start_sound=pygame.mixer.Sound("startpose.wav")
end_sound=pygame.mixer.Sound("endpose.wav")

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.9) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            ready_sound.play()
            cv2.waitKey(3000)
            start_sound.play()
            cv2.waitKey(1000)
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)   
                    cv2.putText(image, 'STARTING', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)
                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
            end_sound.play()
            cv2.waitKey(3000)
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'L': 0}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
# Ok to skip
np.array(sequences).shape
# Out:
# (30, 30, 1662)

# %%
# Ok to skip
np.array(labels).shape
# Out:
# (30,)

# %%
# Ok to skip
X = np.array(sequences)

# %%
# Ok to skip
X.shape
# Out:
# (30, 30, 1662)

# %%
# Ok to skip
y = to_categorical(labels).astype(int)

# %%
# Ok to skip
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10)

# %%
# Ok to skip
y_test.shape
# Out:
# (3, 1)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6899 - categorical_accuracy: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6960 - categorical_accuracy: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.8886 - categorical_accuracy: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2199 - categorical_accuracy: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2811 - categorical_accuracy: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.5429e-05 - categorical_accuracy: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 63ms/step - loss: 6.2513e-07 - categorical_accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.3093e-12 - categorical_accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 64ms/step - loss: 8.7228e-12 - categorical_accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.0789e-18 - categorical_accuracy: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 67ms/step - loss: 2.7692e-13 - categorical_accuracy: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 64ms/step - loss: 3.4870e-15 - categorical_accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 65ms/step - loss: 6.6657e-30 - categorical_accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 65ms/step - loss: 5.6662e-26 - categorical_accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 63ms/step - loss: 7.1244e-38 - categorical_accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 62ms/step - loss: 3.9749e-17 - categorical_accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 63ms/step - loss: 8.6268e-28 - categorical_accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 596,609
# Trainable params: 596,609
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 360ms/step

# %%
actions[np.argmax(res[2])]
# Out:
# 'L'

# %%
actions[np.argmax(y_test[2])]
# Out:
# 'L'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
# Once training is done, u do not have to train it again (no need to call the fit() finction). Just need to setup the model
# and compile it. then load the saved weights.
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['categorical_accuracy'])

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 327ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[0, 0],
#         [0, 3]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[51], line 6, in prob_viz(res, actions, input_frame, colors)
#       4 for num, prob in enumerate(res):
#       5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
# ----> 6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.9) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        #cv2.putText(image, ' '.join(sentence), (3,30), 
        #               cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 18ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# L
